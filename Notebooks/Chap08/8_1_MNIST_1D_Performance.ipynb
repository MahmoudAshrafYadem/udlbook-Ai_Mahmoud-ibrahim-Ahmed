# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to C:\Users\mahmo\AppData\Local\Temp\pip-req-build-s0msvca4
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: requests in d:\PROGRAMS\PYTHON\Lib\site-packages (from mnist1d==0.0.2.post16) (2.32.5)
# Requirement already satisfied: numpy in d:\PROGRAMS\PYTHON\Lib\site-packages (from mnist1d==0.0.2.post16) (2.4.2)
# Requirement already satisfied: matplotlib in d:\PROGRAMS\PYTHON\Lib\site-packages (from mnist1d==0.0.2.post16) (3.10.8)
# Requirement already satisfied: scipy in d:\PROGRAMS\PYTHON\Lib\site-packages (from mnist1d==0.0.2.post16) (1.17.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\PROGRAMS\PYTHON\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\PROGRAMS\PYTHON\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\PROGRAMS\PYTHON\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\PROGRAMS\PYTHON\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\PROGRAMS\PYTHON\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in d:\PROGRAMS\PYTHON\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in d:\PROGRAMS\PYTHON\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\PROGRAMS\PYTHON\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\PROGRAMS\PYTHON\Lib\site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\PROGRAMS\PYTHON\Lib\site-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\PROGRAMS\PYTHON\Lib\site-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\PROGRAMS\PYTHON\Lib\site-packages (from requests->mnist1d==0.0.2.post16) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\PROGRAMS\PYTHON\Lib\site-packages (from requests->mnist1d==0.0.2.post16) (2025.11.12)
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d 'C:\Users\mahmo\AppData\Local\Temp\pip-req-build-s0msvca4'

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(torch.nn.Linear(D_i, D_o));


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  print("Initializing layer")
  if isinstance(layer_in, torch.nn.Linear):
      torch.nn.init.kaiming_normal_(layer_in.weight, a=0)
      torch.nn.init.zeros_(layer_in.bias)



# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.781227, train error 71.12,  test loss 1.795990, test error 72.70
# Epoch     1, train loss 1.691446, train error 68.10,  test loss 1.711036, test error 71.20
# Epoch     2, train loss 1.667965, train error 66.78,  test loss 1.706579, test error 70.30
# Epoch     3, train loss 1.645585, train error 66.22,  test loss 1.688904, test error 68.30
# Epoch     4, train loss 1.632619, train error 65.28,  test loss 1.679835, test error 68.50
# Epoch     5, train loss 1.633394, train error 64.35,  test loss 1.677198, test error 68.10
# Epoch     6, train loss 1.620948, train error 64.68,  test loss 1.667091, test error 65.80
# Epoch     7, train loss 1.626001, train error 65.32,  test loss 1.680776, test error 69.60
# Epoch     8, train loss 1.628718, train error 64.97,  test loss 1.673080, test error 68.60
# Epoch     9, train loss 1.614966, train error 63.90,  test loss 1.669483, test error 68.30
# Epoch    10, train loss 1.600971, train error 63.60,  test loss 1.660122, test error 69.10
# Epoch    11, train loss 1.600798, train error 63.33,  test loss 1.654556, test error 66.10
# Epoch    12, train loss 1.600556, train error 63.15,  test loss 1.654214, test error 66.70
# Epoch    13, train loss 1.599615, train error 63.05,  test loss 1.654079, test error 66.80
# Epoch    14, train loss 1.596699, train error 62.47,  test loss 1.654151, test error 66.10
# Epoch    15, train loss 1.599178, train error 63.22,  test loss 1.663449, test error 67.70
# Epoch    16, train loss 1.599050, train error 63.28,  test loss 1.660909, test error 66.60
# Epoch    17, train loss 1.596187, train error 63.47,  test loss 1.659066, test error 67.60
# Epoch    18, train loss 1.597029, train error 62.53,  test loss 1.664068, test error 66.80
# Epoch    19, train loss 1.598357, train error 62.67,  test loss 1.661746, test error 67.70
# Epoch    20, train loss 1.592887, train error 62.85,  test loss 1.651525, test error 66.80
# Epoch    21, train loss 1.591594, train error 62.15,  test loss 1.653835, test error 66.60
# Epoch    22, train loss 1.592125, train error 62.60,  test loss 1.653410, test error 66.70
# Epoch    23, train loss 1.592243, train error 63.00,  test loss 1.655279, test error 67.20
# Epoch    24, train loss 1.591597, train error 62.53,  test loss 1.651906, test error 66.20
# Epoch    25, train loss 1.592728, train error 62.53,  test loss 1.649995, test error 66.90
# Epoch    26, train loss 1.590979, train error 62.92,  test loss 1.653647, test error 66.90
# Epoch    27, train loss 1.591765, train error 63.28,  test loss 1.652958, test error 67.30
# Epoch    28, train loss 1.590847, train error 63.12,  test loss 1.653823, test error 66.80
# Epoch    29, train loss 1.590694, train error 62.95,  test loss 1.651806, test error 67.40
# Epoch    30, train loss 1.589886, train error 62.58,  test loss 1.654013, test error 67.30
# Epoch    31, train loss 1.589736, train error 62.67,  test loss 1.652037, test error 66.90
# Epoch    32, train loss 1.589740, train error 62.65,  test loss 1.653268, test error 66.80
# Epoch    33, train loss 1.589621, train error 63.05,  test loss 1.652767, test error 66.10
# Epoch    34, train loss 1.589641, train error 62.40,  test loss 1.651955, test error 67.60
# Epoch    35, train loss 1.589379, train error 62.58,  test loss 1.652104, test error 66.90
# Epoch    36, train loss 1.589433, train error 62.85,  test loss 1.654537, test error 66.80
# Epoch    37, train loss 1.589433, train error 62.72,  test loss 1.653410, test error 66.80
# Epoch    38, train loss 1.589286, train error 62.55,  test loss 1.653052, test error 66.90
# Epoch    39, train loss 1.589289, train error 62.62,  test loss 1.652120, test error 67.40
# Epoch    40, train loss 1.589032, train error 62.62,  test loss 1.652392, test error 67.00
# Epoch    41, train loss 1.589045, train error 62.75,  test loss 1.652732, test error 67.30
# Epoch    42, train loss 1.588991, train error 62.70,  test loss 1.653772, test error 66.80
# Epoch    43, train loss 1.588925, train error 62.65,  test loss 1.652236, test error 66.80
# Epoch    44, train loss 1.588925, train error 62.58,  test loss 1.652743, test error 66.90
# Epoch    45, train loss 1.588902, train error 62.65,  test loss 1.652951, test error 67.40
# Epoch    46, train loss 1.588835, train error 62.67,  test loss 1.652318, test error 67.10
# Epoch    47, train loss 1.588833, train error 62.58,  test loss 1.653223, test error 67.10
# Epoch    48, train loss 1.588787, train error 62.67,  test loss 1.652181, test error 66.80
# Epoch    49, train loss 1.588757, train error 62.50,  test loss 1.653102, test error 67.10

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
