# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to C:\Users\mahmo\AppData\Local\Temp\pip-req-build-l1wx7o5m
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: requests in d:\PROGRAMS\PYTHON\Lib\site-packages (from mnist1d==0.0.2.post16) (2.32.5)
# Requirement already satisfied: numpy in d:\PROGRAMS\PYTHON\Lib\site-packages (from mnist1d==0.0.2.post16) (2.4.2)
# Requirement already satisfied: matplotlib in d:\PROGRAMS\PYTHON\Lib\site-packages (from mnist1d==0.0.2.post16) (3.10.8)
# Requirement already satisfied: scipy in d:\PROGRAMS\PYTHON\Lib\site-packages (from mnist1d==0.0.2.post16) (1.17.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\PROGRAMS\PYTHON\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\PROGRAMS\PYTHON\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\PROGRAMS\PYTHON\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\PROGRAMS\PYTHON\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\PROGRAMS\PYTHON\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in d:\PROGRAMS\PYTHON\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in d:\PROGRAMS\PYTHON\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\PROGRAMS\PYTHON\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\PROGRAMS\PYTHON\Lib\site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\PROGRAMS\PYTHON\Lib\site-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\PROGRAMS\PYTHON\Lib\site-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\PROGRAMS\PYTHON\Lib\site-packages (from requests->mnist1d==0.0.2.post16) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\PROGRAMS\PYTHON\Lib\site-packages (from requests->mnist1d==0.0.2.post16) (2025.11.12)
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d 'C:\Users\mahmo\AppData\Local\Temp\pip-req-build-l1wx7o5m'

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cpu

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

    # Loss function
    loss_function = torch.nn.CrossEntropyLoss()

    # Optimizer
    optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

    # Convert data to tensors
    x_train = torch.tensor(data['x'].astype('float32'))
    y_train = torch.tensor(data['y']).long().squeeze()

    x_test = torch.tensor(data['x_test'].astype('float32'))
    y_test = torch.tensor(data['y_test']).long().squeeze()
    # Data loader
    data_loader = DataLoader(
        TensorDataset(x_train, y_train),
        batch_size=100,
        shuffle=True
    )

    for epoch in range(n_epoch):

        model.train()

        # training loop
        for x_batch, y_batch in data_loader:

            optimizer.zero_grad()

            pred = model(x_batch)

            loss = loss_function(pred, y_batch)

            loss.backward()

            optimizer.step()

        # evaluation
        model.eval()

        with torch.no_grad():

            pred_train = model(x_train)
            pred_test = model(x_test)

            _, predicted_train_class = torch.max(pred_train, 1)
            _, predicted_test_class = torch.max(pred_test, 1)

            errors_train = 100 * (predicted_train_class != y_train).float().mean()
            errors_test = 100 * (predicted_test_class != y_test).float().mean()

            losses_train = loss_function(pred_train, y_train).item()
            losses_test = loss_function(pred_test, y_test).item()

        if epoch % 100 == 0:
            print(
                f'Epoch {epoch:5d}, '
                f'train loss {losses_train:.6f}, '
                f'train error {errors_train:3.2f}, '
                f'test loss {losses_test:.6f}, '
                f'test error {errors_test:3.2f}'
            )

    return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?
#
# **Answers (predictions before running):**
#
# The model has two hidden layers of size n_hidden. Total parameters ≈ n_hidden² + 52·n_hidden + 10.
# Setting this equal to 4000 training examples: n_hidden ≈ 42.
#
# 1. Training error will become zero (interpolation threshold) at approximately **n_hidden ≈ 42**, where the number of parameters equals the number of training examples (~4000).
# 2. The first minimum (best generalisation before overfitting) will appear at **low capacity (n_hidden ≈ 5–15)**, where the model captures the signal without fitting the noise.
# 3. The maximum of the double-descent curve (worst test performance) will appear right at the interpolation threshold, around **n_hidden ≈ 42**, where the model barely fits the data and has high variance.

# %%
hidden_variables = np.array([
2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,
70,80,90,100,120,140,160,180,200,250,300,400
])

errors_train_all = np.zeros_like(hidden_variables, dtype=float)
errors_test_all = np.zeros_like(hidden_variables, dtype=float)
total_weights_all = np.zeros_like(hidden_variables, dtype=float)

n_epoch = 1000

for c_hidden in range(len(hidden_variables)):

    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')

    model = get_model(hidden_variables[c_hidden])

    total_weights_all[c_hidden] = count_parameters(model)

    errors_train, errors_test = fit_model(model, data, n_epoch)

    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden] = errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.301057, train error 89.03, test loss 2.303164, test error 89.45
# Epoch   100, train loss 1.926230, train error 71.68, test loss 1.769896, test error 69.85
# Epoch   200, train loss 1.916037, train error 71.43, test loss 1.755272, test error 69.77
# Epoch   300, train loss 1.913181, train error 72.58, test loss 1.743047, test error 69.27
# Epoch   400, train loss 1.908954, train error 70.90, test loss 1.746571, test error 68.93
# Epoch   500, train loss 1.911387, train error 71.68, test loss 1.756680, test error 69.77
# Epoch   600, train loss 1.906770, train error 70.50, test loss 1.737433, test error 69.35
# Epoch   700, train loss 1.906201, train error 72.40, test loss 1.736468, test error 70.17
# Epoch   800, train loss 1.908538, train error 71.72, test loss 1.729070, test error 69.15
# Epoch   900, train loss 1.907274, train error 71.90, test loss 1.730663, test error 69.17
# Training model with   4 hidden variables
# Epoch     0, train loss 2.299109, train error 88.40, test loss 2.299806, test error 88.02
# Epoch   100, train loss 1.802523, train error 65.50, test loss 1.664196, test error 63.78
# Epoch   200, train loss 1.753510, train error 63.65, test loss 1.616602, test error 63.73
# Epoch   300, train loss 1.753998, train error 62.88, test loss 1.629792, test error 63.42
# Epoch   400, train loss 1.741851, train error 62.83, test loss 1.601779, test error 62.48
# Epoch   500, train loss 1.742524, train error 63.48, test loss 1.605328, test error 63.20
# Epoch   600, train loss 1.740827, train error 63.00, test loss 1.601828, test error 62.98
# Epoch   700, train loss 1.746888, train error 63.17, test loss 1.601042, test error 63.15
# Epoch   800, train loss 1.742394, train error 62.35, test loss 1.605187, test error 62.45
# Epoch   900, train loss 1.744847, train error 62.80, test loss 1.624815, test error 63.33
# Training model with   6 hidden variables
# Epoch     0, train loss 2.306482, train error 89.07, test loss 2.310207, test error 88.92
# Epoch   100, train loss 1.702595, train error 61.55, test loss 1.532847, test error 59.47
# Epoch   200, train loss 1.656819, train error 59.68, test loss 1.525626, test error 59.03
# Epoch   300, train loss 1.641682, train error 58.72, test loss 1.517678, test error 58.78
# Epoch   400, train loss 1.636465, train error 58.50, test loss 1.502989, test error 57.62
# Epoch   500, train loss 1.627624, train error 57.83, test loss 1.499420, test error 58.03
# Epoch   600, train loss 1.625505, train error 57.88, test loss 1.504308, test error 57.83
# Epoch   700, train loss 1.622620, train error 57.90, test loss 1.502580, test error 57.58
# Epoch   800, train loss 1.624195, train error 57.70, test loss 1.503112, test error 57.78
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 20
#      16 model = get_model(hidden_variables[c_hidden])
#      18 total_weights_all[c_hidden] = count_parameters(model)
# ---> 20 errors_train, errors_test = fit_model(model, data, n_epoch)
#      22 errors_train_all[c_hidden] = errors_train
#      23 errors_test_all[c_hidden] = errors_test
#
# Cell In[11], line 37, in fit_model(model, data, n_epoch)
#      33     loss = loss_function(pred, y_batch)
#      35     loss.backward()
# ---> 37     optimizer.step()
#      39 # evaluation
#      40 model.eval()
#
# File d:\PROGRAMS\PYTHON\Lib\site-packages\torch\optim\optimizer.py:526, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     521             raise RuntimeError(
#     522                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     523             )
#     525 # pyrefly: ignore [invalid-param-spec]
# --> 526 out = func(*args, **kwargs)
#     527 self._optimizer_step_code()
#     529 # call optimizer step post hooks
#
# File d:\PROGRAMS\PYTHON\Lib\site-packages\torch\optim\optimizer.py:81, in _use_grad_for_differentiable.<locals>._use_grad(*args, **kwargs)
#      79     torch.set_grad_enabled(self.defaults["differentiable"])
#      80     torch._dynamo.graph_break()
# ---> 81     ret = func(*args, **kwargs)
#      82 finally:
#      83     torch._dynamo.graph_break()
#
# File d:\PROGRAMS\PYTHON\Lib\site-packages\torch\optim\sgd.py:127, in SGD.step(self, closure)
#     121 momentum_buffer_list: list[Tensor | None] = []
#     123 has_sparse_grad = self._init_group(
#     124     group, params, grads, momentum_buffer_list
#     125 )
# --> 127 sgd(
#     128     params,
#     129     grads,
#     130     momentum_buffer_list,
#     131     weight_decay=group["weight_decay"],
#     132     momentum=group["momentum"],
#     133     lr=group["lr"],
#     134     dampening=group["dampening"],
#     135     nesterov=group["nesterov"],
#     136     maximize=group["maximize"],
#     137     has_sparse_grad=has_sparse_grad,
#     138     foreach=group["foreach"],
#     139     fused=group["fused"],
#     140     grad_scale=getattr(self, "grad_scale", None),
#     141     found_inf=getattr(self, "found_inf", None),
#     142 )
#     144 if group["momentum"] != 0:
#     145     # update momentum_buffers in state
#     146     for p, momentum_buffer in zip(
#     147         params, momentum_buffer_list, strict=True
#     148     ):
#
# File d:\PROGRAMS\PYTHON\Lib\site-packages\torch\optim\sgd.py:306, in sgd(params, d_p_list, momentum_buffer_list, has_sparse_grad, foreach, fused, grad_scale, found_inf, weight_decay, momentum, lr, dampening, nesterov, maximize)
#     303 else:
#     304     func = _single_tensor_sgd
# --> 306 func(
#     307     params,
#     308     d_p_list,
#     309     momentum_buffer_list,
#     310     weight_decay=weight_decay,
#     311     momentum=momentum,
#     312     lr=lr,
#     313     dampening=dampening,
#     314     nesterov=nesterov,
#     315     has_sparse_grad=has_sparse_grad,
#     316     maximize=maximize,
#     317     grad_scale=grad_scale,
#     318     found_inf=found_inf,
#     319 )
#
# File d:\PROGRAMS\PYTHON\Lib\site-packages\torch\optim\sgd.py:365, in _single_tensor_sgd(params, grads, momentum_buffer_list, grad_scale, found_inf, weight_decay, momentum, lr, dampening, nesterov, maximize, has_sparse_grad)
#     363     momentum_buffer_list[i] = buf
#     364 else:
# --> 365     buf.mul_(momentum).add_(grad, alpha=1 - dampening)
#     367 if nesterov:
#     368     grad = grad.add(buf, alpha=momentum)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
